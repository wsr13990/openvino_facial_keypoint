# %%
from facenet_pytorch import InceptionResnetV1

# %%
# For a model pretrained on VGGFace2
model = InceptionResnetV1(pretrained='vggface2').eval()

# For a model pretrained on CASIA-Webface
model = InceptionResnetV1(pretrained='casia-webface').eval()

# For an untrained model with 100 classes
model = InceptionResnetV1(num_classes=100).eval()

# For an untrained 1001-class classifier
model = InceptionResnetV1(classify=True, num_classes=1001).eval()
# Out:
# Downloading parameters (1/2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2b99da02e244> in <module>
#       1 # For a model pretrained on VGGFace2
# ----> 2 model = InceptionResnetV1(pretrained='vggface2').eval()
#       3
#       4 # For a model pretrained on CASIA-Webface
#       5 model = InceptionResnetV1(pretrained='casia-webface').eval()
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\facenet_pytorch\models\inception_resnet_v1.py in __init__(self, pretrained, classify, num_classes, dropout_prob, device)
#     259
#     260         if pretrained is not None:
# --> 261             load_weights(self, pretrained)
#     262
#     263         if self.num_classes is not None:
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\facenet_pytorch\models\inception_resnet_v1.py in load_weights(mdl, name)
#     330             s = requests.Session()
#     331             s.mount('https://', HTTPAdapter(max_retries=10))
# --> 332             r = s.get(path, allow_redirects=True)
#     333             with open(cached_file, 'wb') as f:
#     334                 f.write(r.content)
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     656
#     657         if not stream:
# --> 658             r.content
#     659
#     660         return r
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\models.py in content(self)
#     821                 self._content = None
#     822             else:
# --> 823                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     824
#     825         self._content_consumed = True
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# ~\AppData\Roaming\Python\Python36\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~\AppData\Roaming\Python\Python36\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     599                 if self.chunk_left == 0:
#     600                     break
# --> 601                 chunk = self._handle_chunk(amt)
#     602                 decoded = self._decode(chunk, decode_content=decode_content,
#     603                                        flush_decoder=False)
#
# ~\AppData\Roaming\Python\Python36\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#     555             self.chunk_left = None
#     556         elif amt < self.chunk_left:
# --> 557             value = self._fp._safe_read(amt)
#     558             self.chunk_left = self.chunk_left - amt
#     559             returned_chunk = value
#
# ~\Anaconda3\envs\pytorch\lib\http\client.py in _safe_read(self, amt)
#     610         s = []
#     611         while amt > 0:
# --> 612             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     613             if not chunk:
#     614                 raise IncompleteRead(b''.join(s), amt)
#
# ~\Anaconda3\envs\pytorch\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\AppData\Roaming\Python\Python36\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
